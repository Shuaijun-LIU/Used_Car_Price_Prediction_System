# %% [markdown]
# In the first step, we get the user's preferred car brands based on the data of the most popular car brands in the US in the last 5 years.
#
# 1. The brand columns were counted using the `value_counts()` method to determine the number of occurrences of each brand in the last 5 years to determine its popularity.
#
# 2. Finally, the top 15 brands with the highest number of occurrences are selected and their occurrences are returned as a Series.

# %%
import pandas as pd

# Data for the most popular car brands in the US over the last 5 years
data = {
    "Year": [
        "2020", "2020", "2020", "2020", "2020", "2020", "2020", "2020", "2020", "2020", "2020", "2020", "2020", "2020", "2020",
        "2021", "2021", "2021", "2021", "2021", "2021", "2021", "2021", "2021", "2021", "2021", "2021", "2021", "2021", "2021",
        "2022", "2022", "2022", "2022", "2022", "2022", "2022", "2022", "2022", "2022", "2022", "2022", "2022", "2022", "2022",
        "2023", "2023", "2023", "2023", "2023", "2023", "2023", "2023", "2023", "2023", "2023", "2023", "2023", "2023", "2023",
        "2024", "2024", "2024", "2024", "2024", "2024", "2024", "2024", "2024", "2024", "2024", "2024", "2024", "2024", "2024"
    ],
    "Brand": [
        "Ford", "Toyota", "Chevrolet", "Honda", "Nissan", "Jeep", "Subaru", "Hyundai", "Kia", "RAM", 
        "GMC", "Mercedes-Benz", "Volkswagen", "BMW", "Mazda",
        "Ford", "Toyota", "Chevrolet", "Honda", "Nissan", "Jeep", "Subaru", "Hyundai", "Kia", "RAM", 
        "GMC", "Mercedes-Benz", "Volkswagen", "BMW", "Mazda",
        "Ford", "Toyota", "Chevrolet", "Honda", "Nissan", "Jeep", "Subaru", "Hyundai", "Kia", "RAM", 
        "GMC", "Mercedes-Benz", "Volkswagen", "BMW", "Tesla",
        "Ford", "Toyota", "Chevrolet", "Honda", "Hyundai", "Kia", "Subaru", "Tesla", "Nissan", "Jeep", 
        "RAM", "GMC", "Mercedes-Benz", "Volkswagen", "BMW",
        "Ford", "Toyota", "Chevrolet", "Honda", "Hyundai", "Kia", "Mazda", "Subaru", "Tesla", "Lexus", 
        "Nissan", "Jeep", "RAM", "GMC", "Mercedes-Benz"
    ]
}

# Convert the data into a DataFrame
df = pd.DataFrame(data)

# Count the occurrences of each brand over the 5-year period to determine popularity
brand_popularity = df["Brand"].value_counts().head(15)

brand_popularity
# Out:
# Brand
# Ford             5
# Hyundai          5
# Mercedes-Benz    5
# GMC              5
# RAM              5
# Toyota           5
# Kia              5
# Subaru           5
# Jeep             5
# Nissan           5
# Honda            5
# Chevrolet        5
# Volkswagen       4
# BMW              4
# Mazda            3
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

# Create a bar plot for brand popularity
plt.figure(figsize=(10, 6))
brand_popularity.plot(kind='bar', color='skyblue')
plt.title('Top 15 Most Popular Car Brands in the US (2020-2024)')
plt.xlabel('Brand')
plt.ylabel('Number of Occurrences')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
